#url.remove(' https://www.vanguardngr.com/2024/03/state-of-the-nation-we-cant-continue-like-this-prof-obiora-okonkwo/')
print(len(url))
for i in range(len(url)):
  from newspaper import Article
  data=Article(url[i])
  data.download()
  data.parse()
  article_data=data.text
  print(article_data)
  with open(f"C:\\Users\\FACULTY OFFICIAL\\Documents\\Scraped Data\\News\\Scrape_Data{i}.txt",'w') as f:
    f_val=f.write(article_data)
 
#vanguard base_url/category/query
#punch    base_url/topics/query
#arise     base_url/topics/query
# Out:
# 33
# In May 2021, a 96 year-old businessman died in Rome, Italy. In his lifetime, Ahmed Idris Nasreddin might have amassed a personal fortune of close to half a billion dollars, but the death of NASCO Group’s multimillionaire founder barely made the news. At first glance, the only extraordinary thing about his life story was that it embodied the African entrepreneurship dream.
#
# Nasreddin was an Eritrean who moved to Jos in Nigeria’s Plateau State, and grew his father’s small manufacturing business into a $460 million conglomerate involved in everything from breakfast cereal and confectionery to pharmaceuticals, real estate and energy. After many years of growth and success, he eventually handed his sprawling business empire over to his son Attia Nasreddin, and retired at an old, satisfied age.
#
# In an official statement released after Nasreddin’s death in May, Plateau State governor Simon Lalong said:
#
# ...

# %%
urL=['https://punchng.com/npfl-sporting-thrash-remo-4-1-in-southwest-derby/','https://punchng.com/caged/','https://punchng.com/jo-bonfrere-endorses-amuneke-for-eagles-job/','https://punchng.com/80-golfers-for-acropolis-golf-course-launch/',
     'https://www.vanguardngr.com/2024/03/super-eagles-job-who-succeeds-peseiro/','https://www.vanguardngr.com/2024/03/fury-hails-joshua-over-ngannou-knockout-says-im-ready-to-fight-him/',
     'https://www.vanguardngr.com/2024/03/ndlea-npfl-partner-on-drug-test-for-footballers/','https://www.vanguardngr.com/2024/03/african-games-uganda-stuns-flying-eagles-2-1-in-football-opener/','https://www.vanguardngr.com/2024/03/i-can-never-say-no-to-nigeria-enyeama/',
     'https://www.vanguardngr.com/2024/03/nigerian-striker-moses-ebiye-promises-to-make-impact-at-motherwell/','https://www.vanguardngr.com/2024/03/2023-african-games-quadri-wins-nigerias-second-medal-in-table-tennis/',
     'https://www.vanguardngr.com/2024/03/anthony-joshua-to-get-n64bn-from-ngannou-fight/','https://www.vanguardngr.com/2024/03/rivers-united-snatch-dramatic-win-and-last-eight-place/','https://www.vanguardngr.com/2024/03/why-we-introduced-u-17-youth-league-npfl/',
     'https://www.vanguardngr.com/2024/03/enough-of-foreign-coaches-odegbami-tells-nff/','https://www.vanguardngr.com/2024/02/osimhen-bags-hat-trick-as-napoli-hit-six-past-sassuolo/',
     'https://www.vanguardngr.com/2024/02/osimhen-bags-hat-trick-as-napoli-hit-six-past-sassuolo/','https://www.vanguardngr.com/2024/02/maduka-okoye-im-ready-for-return-to-super-eagles/','https://www.vanguardngr.com/2024/03/internal-squabble-sinking-nigerias-basketball/','https://www.vanguardngr.com/2024/03/dambe-warriors-talk-tough-ahead-super-fight-2-in-lagos/',
     'https://www.vanguardngr.com/2024/03/why-im-pushing-osimhen-to-join-chelsea-mikel-obi-reveals/','https://www.vanguardngr.com/2024/03/osimhen-boniface-oshoala-makes-list-for-10th-nigeria-pitch-awards-see-full-list/','https://www.vanguardngr.com/2024/03/nogig-2024-nlng-nnpc-others-qualify-for-semi-finals-of-football-event/'
      ]
'''headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
html_content = response.text'''

for i in range(len(urL)):
  from newspaper import Article
  data=Article(urL[i])
  data.download()
  data.parse()
  article_data=data.text
  print(article_data)
  with open(f"C:\\Users\\FACULTY OFFICIAL\\Documents\\Scraped Data\\Sports\\Scrape_Data{i}.txt",'w',encoding='utf-8') as f:
    f_val=f.write(article_data)
# Out:
# Sporting Lagos claimed the bragging rights in the second installment of the new southwest derby in the Nigeria Premier Football League with an emphatic 4-1 win over Remo Stars at the Mobolaji Johnson Arena, Onikan, Lagos on Sunday, PUNCH Sports Extra reports.
#
# The Ikenne side were undone by three of their former players in the ranks of Sporting, with Junior Lokosa, Godwin Odibo and Philip Odubia all involved.
#
# Odibo won a penalty inside five minutes and Lokosa made no mistake from the spot to give Paul Offor’s side the lead while Paschal Durugbor doubled the advantage in the 27th minute.
#
# A 38th minute own goal by defender Salaudeen Aliu reduced the deficit for Rem before halftime but the hosts came back with full throttle in the second half, as Odubia netted two more goals to see off the game 4-1.
#
# In Aba, Chijioke Mbaoma moved to the top of the goalscorers chart with his 12th goal of the season in Enyimba’s 1-0 win over Doma United.
#
# ...

# %% [markdown]
# # Automated Approach

# %%
from newspaper import Article

base_url="https://www.arise.tv/"

def search(base_url,term,page):
    url=f"{base_url}/'category'/?s={term}/"
    links=scrape_links(url)
    print(links)
    for link in links:
       article = Article(link)
       try:
         article.download()
         article.parse()
       except Exception as e:
        print(link)
       article_text = article.text
       return(article_text)

def scrape_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = [link.get('href') for link in soup.find_all('a') if link.get('href')]
    return links
''' 
    try:
        if page == 1:
            url = f"{base_url}/?s={search_query}"
        else:
            url = f"{base_url}/page/{page}/?s={search_query}"

        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
# Find and process each article on the current page
        articles = soup.find_all('article')  # Adjust if necessary to target specific articles
        for article in articles:
            a_link = article.find('a', href=True)['href']
            print(f"Processing article: {a_link}")
            get_article(a_link)
'''
# Out:
# ' \n    try:\n        if page == 1:\n            url = f"{base_url}/?s={search_query}"\n        else:\n            url = f"{base_url}/page/{page}/?s={search_query}"\n\n        response = requests.get(url)\n        soup = BeautifulSoup(response.content, \'html.parser\')\n# Find and process each article on the current page\n        articles = soup.find_all(\'article\')  # Adjust if necessary to target specific articles\n        for article in articles:\n            a_link = article.find(\'a\', href=True)[\'href\']\n            print(f"Processing article: {a_link}")\n            get_article(a_link)\n'

# %%
search(base_url,'sports',1)
# Out:
# ['/', 'https://www.arise.tv', 'https://www.arise.tv/category/breaking/', 'https://www.arise.tv/category/global/', 'https://www.arise.tv/category/regional/', 'https://www.arise.tv/category/business/', 'https://www.arise.tv/category/politics/', 'https://www.arise.tv/category/entertainment/', 'https://www.arise.tv/category/sports/', 'https://www.arise.tv/category/tech/', 'https://www.arise.tv/category/health/', 'https://www.arise.tv/videos/', '#arisemenu', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#arisemenu', 'https://www.arise.tv/tension-in-senate-as-jimoh-ibrahim-asks-igp-to-arrest-prosecute-ningi/', 'https://www.arise.tv/shameful-peter-obi-slams-alleged-budget-padding-as-breach-of-public-trust/', 'https://www.arise.tv/gunmen-invade-plateau-market-kill-seven/', 'https://www.arise.tv/amid-incessant-power-cuts-vandals-attack-shiroro-katampe-transmission-line/', 'https://www.facebook.com/AriseTVNews/', 'https://twitter.com/ARISEtv', 'https://www.youtube.com/chann
# ...

# %%
scrape_links('https://www.arise.tv/category/sports')
# Out:
# []

# %%
if 'category/sports' not in  'https://www.arise.tv/category/tech/':
    print("O!!")
# Out:
# O!!
